# %%
import urllib

# %%
url = "https://raw.githubusercontent.com/GokuMohandas/MadeWithML/4ad626098aca25db5628fe67895e738d5a5c2c2a/data/titanic.csv"
response = urllib.request.urlopen(url)
html = response.read()
with open('titanic.csv', 'wb') as f:
    f.write(html)

# %%
ls -l
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 72EC-B50D
#
#  Directory of C:\Users\Nambi
# File Not Found

# %%
import pandas as pd

# %%
# Read from CSV to Pandas DataFrame
df = pd.read_csv("titanic.csv", header=0)

# %%
# First five items
df.head()
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked  survived
# 0      0      0   24160  211.3375       B5        S         1
# 1      1      2  113781  151.5500  C22 C26        S         1
# 2      1      2  113781  151.5500  C22 C26        S         0
# 3      1      2  113781  151.5500  C22 C26        S         0
# 4      1      2  113781  151.5500  C22 C26        S         0

# %%
# Describe features
df.describe()
# Out:
#             pclass          age        sibsp        parch         fare  \
# count  1309.000000  1046.000000  1309.000000  1309.000000  1308.000000
# mean      2.294882    29.881135     0.498854     0.385027    33.295479
# std       0.837836    14.413500     1.041658     0.865560    51.758668
# min       1.000000     0.166700     0.000000     0.000000     0.000000
# 25%       2.000000    21.000000     0.000000     0.000000     7.895800
# 50%       3.000000    28.000000     0.000000     0.000000    14.454200
# 75%       3.000000    39.000000     1.000000     0.000000    31.275000
# max       3.000000    80.000000     8.000000     9.000000   512.329200
#
#           survived
# count  1309.000000
# mean      0.381971
# std       0.486055
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
# Histograms
df["age"].hist()
# Out:
# <AxesSubplot:>

# %%
# Unique values
df["embarked"].unique()
# Out:
# array(['S', 'C', nan, 'Q'], dtype=object)

# %%
# Selecting data by feature
df["name"].head()
# Out:
# 0                      Allen, Miss. Elisabeth Walton
# 1                     Allison, Master. Hudson Trevor
# 2                       Allison, Miss. Helen Loraine
# 3               Allison, Mr. Hudson Joshua Creighton
# 4    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# Name: name, dtype: object

# %%
# Filtering
df[df["sex"]=="female"].head() # only the female data appear
# Out:
#    pclass                                             name     sex   age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0
# 2       1                     Allison, Miss. Helen Loraine  female   2.0
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0
# 6       1                Andrews, Miss. Kornelia Theodosia  female  63.0
# 8       1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0
#
#    sibsp  parch  ticket      fare    cabin embarked  survived
# 0      0      0   24160  211.3375       B5        S         1
# 2      1      2  113781  151.5500  C22 C26        S         0
# 4      1      2  113781  151.5500  C22 C26        S         0
# 6      1      0   13502   77.9583       D7        S         1
# 8      2      0   11769   51.4792     C101        S         1

# %%
df["age"]
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
df["age"].head()
# Out:
# 0    29.0000
# 1     0.9167
# 2     2.0000
# 3    30.0000
# 4    25.0000
# Name: age, dtype: float64

# %%
df["age"].hist()
# Out:
# <AxesSubplot:>

# %%
df["age"].max()
# Out:
# 80.0

# %%
df["age"]==20.0000
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1304    True
# 1305    True
# 1306    True
# 1307    True
# 1308    True
# Name: age, Length: 1309, dtype: bool

# %%
df.sort_values("fare", ascending=False).head()
# Out:
#      pclass                                               name     sex   age  \
# 183       1                             Lesurer, Mr. Gustave J    male  20.0
# 302       1                                   Ward, Miss. Anna  female  20.0
# 49        1                 Cardeza, Mr. Thomas Drake Martinez    male  20.0
# 50        1  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  20.0
# 113       1                         Fortune, Miss. Mabel Helen  female  20.0
#
#      sibsp  parch    ticket      fare        cabin embarked  survived
# 183      0      0  PC 17755  512.3292         B101        C         1
# 302      0      0  PC 17755  512.3292          NaN        C         1
# 49       0      1  PC 17755  512.3292  B51 B53 B55        C         1
# 50       0      1  PC 17755  512.3292  B51 B53 B55        C         1
# 113      3      2     19950  263.0000  C23 C25 C27        S         1

# %%
df["age"]==20.0000
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1304    True
# 1305    True
# 1306    True
# 1307    True
# 1308    True
# Name: age, Length: 1309, dtype: bool

# %%
len(df[df['fare'] == 512.3292])
# Out:
# 4

# %%
df["embarked"].unique()
# Out:
# array(['S', 'C', nan, 'Q'], dtype=object)

# %%
df[df["sex"]=='female']
# Out:
#       pclass                                             name     sex   age  \
# 0          1                    Allen, Miss. Elisabeth Walton  female  20.0
# 2          1                     Allison, Miss. Helen Loraine  female  20.0
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  20.0
# 6          1                Andrews, Miss. Kornelia Theodosia  female  20.0
# 8          1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  20.0
# ...      ...                                              ...     ...   ...
# 1286       3  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)  female  20.0
# 1290       3                 Wilkes, Mrs. James (Ellen Needs)  female  20.0
# 1300       3          Yasbeck, Mrs. Antoni (Selini Alexander)  female  20.0
# 1304       3                             Zabour, Miss. Hileni  female  20.0
# 1305       3                            Zabour, Miss. Thamine  female  20.0
#
# ...

# %%
df[df["sex"]=='female'].head()
# Out:
#    pclass                                             name     sex   age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  20.0
# 2       1                     Allison, Miss. Helen Loraine  female  20.0
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  20.0
# 6       1                Andrews, Miss. Kornelia Theodosia  female  20.0
# 8       1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  20.0
#
#    sibsp  parch  ticket      fare    cabin embarked  survived
# 0      0      0   24160  211.3375       B5        S         1
# 2      1      2  113781  151.5500  C22 C26        S         0
# 4      1      2  113781  151.5500  C22 C26        S         0
# 6      1      0   13502   77.9583       D7        S         1
# 8      2      0   11769   51.4792     C101        S         1

# %%
len(df[df["sex"]=='female'])
# Out:
# 466

# %%
groupbySex=df.groupby('sex')
groupbySex.size()
# Out:
# sex
# female    466
# male      843
# dtype: int64

# %%
groupbySex.mean()
# Out:
#           pclass   age     sibsp     parch       fare  survived
# sex
# female  2.154506  20.0  0.652361  0.633047  46.198097  0.727468
# male    2.372479  20.0  0.413998  0.247924  26.154601  0.190985

# %%
# Rows with at least one NaN value
df[pd.isnull(df).any(axis=1)].head()
# Out:
#     pclass                          name     sex   age  sibsp  parch  \
# 9        1       Artagaveytia, Mr. Ramon    male  20.0      0      0
# 13       1  Barber, Miss. Ellen "Nellie"  female  20.0      0      0
# 15       1           Baumann, Mr. John D    male  20.0      0      0
# 23       1         Bidois, Miss. Rosalie  female  20.0      0      0
# 25       1           Birnbaum, Mr. Jakob    male  20.0      0      0
#
#       ticket      fare cabin embarked  survived
# 9   PC 17609   49.5042   NaN        C         0
# 13     19877   78.8500   NaN        S         1
# 15  PC 17318   25.9250   NaN        S         0
# 23  PC 17757  227.5250   NaN        C         1
# 25     13905   26.0000   NaN        C         0

# %%
len(df[pd.isnull(df).any(axis=1)])
# Out:
# 1016

# %%
# Drop rows with Nan values
df = df.dropna() # removes rows with any NaN values
df = df.reset_index() # reset's row indexes in case any rows were dropped
df.head()
# Out:
#    index  pclass                                             name     sex  \
# 0      0       1                    Allen, Miss. Elisabeth Walton  female
# 1      1       1                   Allison, Master. Hudson Trevor    male
# 2      2       1                     Allison, Miss. Helen Loraine  female
# 3      3       1             Allison, Mr. Hudson Joshua Creighton    male
# 4      4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#     age  sibsp  parch  ticket      fare    cabin embarked  survived
# 0  20.0      0      0   24160  211.3375       B5        S         1
# 1  20.0      1      2  113781  151.5500  C22 C26        S         1
# 2  20.0      1      2  113781  151.5500  C22 C26        S         0
# 3  20.0      1      2  113781  151.5500  C22 C26        S         0
# 4  20.0      1      2  113781  151.5500  C22 C26        S         0

# %%
# Dropping multiple columns
df = df.drop(["cabin"], axis=1) # we won't use text features for our initial basic models
df.head()
# Out:
#    index  pclass                                             name     sex  \
# 0      0       1                    Allen, Miss. Elisabeth Walton  female
# 1      1       1                   Allison, Master. Hudson Trevor    male
# 2      2       1                     Allison, Miss. Helen Loraine  female
# 3      3       1             Allison, Mr. Hudson Joshua Creighton    male
# 4      4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#     age  sibsp  parch  ticket      fare embarked  survived
# 0  20.0      0      0   24160  211.3375        S         1
# 1  20.0      1      2  113781  151.5500        S         1
# 2  20.0      1      2  113781  151.5500        S         0
# 3  20.0      1      2  113781  151.5500        S         0
# 4  20.0      1      2  113781  151.5500        S         0

# %%
# Map feature values: Alter column values using map
df['sex'] = df['sex'].map( {'female': 0, 'male': 1} ).astype(int)
df["embarked"] = df['embarked'].dropna().map( {'S':0, 'C':1, 'Q':2} ).astype(int)
df.head()
# Out:
#    index  pclass                                             name  sex   age  \
# 0      0       1                    Allen, Miss. Elisabeth Walton    0  20.0
# 1      1       1                   Allison, Master. Hudson Trevor    1  20.0
# 2      2       1                     Allison, Miss. Helen Loraine    0  20.0
# 3      3       1             Allison, Mr. Hudson Joshua Creighton    1  20.0
# 4      4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    0  20.0
#
#    sibsp  parch  ticket      fare  embarked  survived
# 0      0      0   24160  211.3375         0         1
# 1      1      2  113781  151.5500         0         1
# 2      1      2  113781  151.5500         0         0
# 3      1      2  113781  151.5500         0         0
# 4      1      2  113781  151.5500         0         0

# %%
# Lambda expressions to create new features: Alter column value based on function
def get_family_size(sibsp, parch):
    family_size = sibsp + parch
    return family_size
# add new column family_size
df["family_size"] = df[["sibsp", "parch"]].apply(lambda x: get_family_size(x["sibsp"], x["parch"]), axis=1)
df.head()
# Out:
#    index  pclass                                             name  sex   age  \
# 0      0       1                    Allen, Miss. Elisabeth Walton    0  20.0
# 1      1       1                   Allison, Master. Hudson Trevor    1  20.0
# 2      2       1                     Allison, Miss. Helen Loraine    0  20.0
# 3      3       1             Allison, Mr. Hudson Joshua Creighton    1  20.0
# 4      4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    0  20.0
#
#    sibsp  parch  ticket      fare  embarked  survived  family_size
# 0      0      0   24160  211.3375         0         1            0
# 1      1      2  113781  151.5500         0         1            3
# 2      1      2  113781  151.5500         0         0            3
# 3      1      2  113781  151.5500         0         0            3
# 4      1      2  113781  151.5500         0         0            3

# %%
# Reorganize headers
df = df[['pclass', 'sex', 'age', 'sibsp', 'parch', 'family_size', 'fare', 'embarked', 'survived']]
df.head()
# Out:
#    pclass  sex   age  sibsp  parch  family_size      fare  embarked  survived
# 0       1    0  20.0      0      0            0  211.3375         0         1
# 1       1    1  20.0      1      2            3  151.5500         0         1
# 2       1    0  20.0      1      2            3  151.5500         0         0
# 3       1    1  20.0      1      2            3  151.5500         0         0
# 4       1    0  20.0      1      2            3  151.5500         0         0

# %%
# Saving dataframe to CSV
df.to_csv("processed_titanic.csv", index=False)

# %%
ls -l
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 72EC-B50D
#
#  Directory of C:\Users\Nambi
# File Not Found
